# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
##Dataset
sent=["the glass of milk",
      "the glass of juice",
      "the cup of tea",
      "I am a good boy",
      "I am a good developer",
      "understand the meaning of words",
      "your videos are good"]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## define the Vocabulary size
voc_size=10000

# %%
## one_hot representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]

# %%
one_hot_repr
# Out:
# [[1633, 8772, 6446, 7434],
#  [1633, 8772, 6446, 23],
#  [1633, 3025, 6446, 6392],
#  [8081, 4137, 5512, 9804, 4562],
#  [8081, 4137, 5512, 9804, 1661],
#  [2873, 1633, 9948, 6446, 8732],
#  [5011, 3855, 277, 9804]]

# %%
### word embedding represention
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 1633, 8772, 6446, 7434],
#        [   0,    0,    0,    0, 1633, 8772, 6446,   23],
#        [   0,    0,    0,    0, 1633, 3025, 6446, 6392],
#        [   0,    0,    0, 8081, 4137, 5512, 9804, 4562],
#        [   0,    0,    0, 8081, 4137, 5512, 9804, 1661],
#        [   0,    0,    0, 2873, 1633, 9948, 6446, 8732],
#        [   0,    0,    0,    0, 5011, 3855,  277, 9804]], dtype=int32)

# %%
## feature repersentation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])

# %%
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# array([[[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04641574,  0.03141369, -0.03761629, -0.00095133,
#          -0.02490293, -0.00776396,  0.00460093,  0.02588414,
#          -0.00767318, -0.02567844],
#         [ 0.01549507,  0.01054343,  0.0257789 ,  0.04646888,
#          -0.00495696, -0.02035911, -0.01968479, -0.03267949,
#           0.02740992, -0.02121134],
#         [ 0.00063298, -0.04661012,  0.04689281,  0.04784599,
#          -0.04870138, -0.03259567,  0.03175852,  0.00173008,
#           0.01288647, -0.00466158],
#         [ 0.02413399,  0.04149047,  0.01566123, -0.03308319,
#           0.04737041,  0.03403914,  0.04086411, -0.01778389,
#          -0.02550855,  0.04832793]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04641574,  0.03141369, -0.03761629, -0.00095133,
#          -0.02490293, -0.00776396,  0.00460093,  0.02588414,
#          -0.00767318, -0.02567844],
#         [ 0.01549507,  0.01054343,  0.0257789 ,  0.04646888,
#          -0.00495696, -0.02035911, -0.01968479, -0.03267949,
#           0.02740992, -0.02121134],
#         [ 0.00063298, -0.04661012,  0.04689281,  0.04784599,
#          -0.04870138, -0.03259567,  0.03175852,  0.00173008,
#           0.01288647, -0.00466158],
#         [-0.03205935,  0.00056089,  0.01740715, -0.04460064,
#          -0.01527295, -0.04697148, -0.03691362, -0.04285758,
#          -0.0358556 ,  0.033808  ]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04641574,  0.03141369, -0.03761629, -0.00095133,
#          -0.02490293, -0.00776396,  0.00460093,  0.02588414,
#          -0.00767318, -0.02567844],
#         [-0.01372489,  0.01847081, -0.04572111,  0.03928998,
#           0.00860701,  0.04736404,  0.03647672,  0.04083505,
#           0.0283819 , -0.01418959],
#         [ 0.00063298, -0.04661012,  0.04689281,  0.04784599,
#          -0.04870138, -0.03259567,  0.03175852,  0.00173008,
#           0.01288647, -0.00466158],
#         [-0.01951944,  0.01317174, -0.00491882, -0.0389189 ,
#          -0.03394009,  0.03480513, -0.04387046,  0.01195915,
#          -0.04304825,  0.03495617]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [-0.04560998,  0.01056129, -0.00199795, -0.03318825,
#           0.00347644, -0.0230439 , -0.0252404 ,  0.04659695,
#           0.02052524, -0.00728767],
#         [-0.03616332,  0.01517966, -0.03603238,  0.03622875,
#           0.00591062, -0.04645441, -0.04736996, -0.04508746,
#          -0.01029054, -0.01823283],
#         [ 0.03914026, -0.01169246, -0.02137102, -0.03427172,
#          -0.03663722, -0.01460754,  0.02678059,  0.0338412 ,
#           0.01180115, -0.00164111],
#         [ 0.00903258, -0.03615382,  0.02413756, -0.01574937,
#           0.02474068, -0.01035025,  0.0288257 , -0.01458038,
#           0.00749958, -0.04033083],
#         [ 0.01618997,  0.04370873, -0.00181302, -0.00503982,
#           0.04589857, -0.0362566 , -0.02453758,  0.01856389,
#          -0.04708393, -0.04683573]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [-0.04560998,  0.01056129, -0.00199795, -0.03318825,
#           0.00347644, -0.0230439 , -0.0252404 ,  0.04659695,
#           0.02052524, -0.00728767],
#         [-0.03616332,  0.01517966, -0.03603238,  0.03622875,
#           0.00591062, -0.04645441, -0.04736996, -0.04508746,
#          -0.01029054, -0.01823283],
#         [ 0.03914026, -0.01169246, -0.02137102, -0.03427172,
#          -0.03663722, -0.01460754,  0.02678059,  0.0338412 ,
#           0.01180115, -0.00164111],
#         [ 0.00903258, -0.03615382,  0.02413756, -0.01574937,
#           0.02474068, -0.01035025,  0.0288257 , -0.01458038,
#           0.00749958, -0.04033083],
#         [ 0.03898736,  0.00614779, -0.01028387,  0.04207003,
#           0.02031452,  0.0031188 , -0.04265371,  0.04745717,
#          -0.03549642,  0.03462538]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [-0.02642075, -0.01670307, -0.01726379, -0.04025092,
#          -0.0434921 , -0.01599369,  0.04367076,  0.00154675,
#          -0.00500969,  0.03665713],
#         [ 0.04641574,  0.03141369, -0.03761629, -0.00095133,
#          -0.02490293, -0.00776396,  0.00460093,  0.02588414,
#          -0.00767318, -0.02567844],
#         [ 0.00409833,  0.00539396,  0.03066022,  0.02187313,
#           0.00524505,  0.01591898, -0.01176663, -0.01212872,
#          -0.01099253, -0.03998492],
#         [ 0.00063298, -0.04661012,  0.04689281,  0.04784599,
#          -0.04870138, -0.03259567,  0.03175852,  0.00173008,
#           0.01288647, -0.00466158],
#         [ 0.03474982, -0.04058085,  0.03436771, -0.03323442,
#          -0.01425005, -0.03748164,  0.04093765,  0.04374265,
#          -0.04843776, -0.03997128]],
#
#        [[ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [ 0.04849351,  0.04086396, -0.02868748, -0.03643619,
#           0.04201693, -0.03013834, -0.03693943, -0.04145147,
#          -0.04159977, -0.04988222],
#         [-0.00566952,  0.04865224, -0.02058052,  0.01660384,
#           0.03928239,  0.03330295,  0.02976263,  0.03325485,
#          -0.027258  , -0.01903992],
#         [ 0.04203874,  0.02212478,  0.04456623,  0.01464031,
#           0.01019611, -0.03114469,  0.00117066, -0.00389733,
#           0.01273001, -0.01033987],
#         [ 0.0370281 , -0.02316593,  0.02115668, -0.01465124,
#           0.04502363, -0.02282341,  0.01710166,  0.04677171,
#           0.01564907,  0.04897356],
#         [ 0.00903258, -0.03615382,  0.02413756, -0.01574937,
#           0.02474068, -0.01035025,  0.0288257 , -0.01458038,
#           0.00749958, -0.04033083]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 1633, 8772, 6446, 7434], dtype=int32)
